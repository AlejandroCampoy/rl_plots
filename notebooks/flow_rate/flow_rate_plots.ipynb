# %% [markdown]
# # Uponor plots

# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import plotly.express as px
import plotly.graph_objects as go
from src.utils.uponor_plots import *
import pandas as pd
import numpy as np
from pprint import pprint
from copy import deepcopy
from datetime import datetime

# %% [markdown]
# ## Load data

# %%
evaluation_obs = {
    'short_cycling_2T': pd.read_csv('data/source/2T/Eplus-PPO-load-example-case2_2025-07-17_09:28-res1/episode-10/monitor/observations.csv'),
    'short_cycling_3T': pd.read_csv('data/source/3T/Eplus-PPO-load-example-case2_2025-07-17_09:20-res1/episode-10/monitor/observations.csv'),
    'short_cycling_4T': pd.read_csv('data/source/4T/Eplus-PPO-load-example-case2_2025-07-17_09:12-res1/episode-10/monitor/observations.csv'),
    'short_cycling_5T': pd.read_csv('data/source/5T/Eplus-PPO-load-example-case2_2025-07-17_09:01-res1/episode-8/monitor/observations.csv'),
    'short_cycling_6T': pd.read_csv('data/source/6T/Eplus-PPO-load-example-case2_2025-07-17_08:54-res1/episode-10/monitor/observations.csv'),
    'short_cycling_7T': pd.read_csv('data/source/7T/Eplus-PPO-load-example-case2_2025-07-17_08:42-res1/episode-10/monitor/observations.csv'),
    'short_cycling_8T': pd.read_csv('data/source/8T/Eplus-PPO-load-example-case2_2025-07-17_07:44-res1/episode-10/monitor/observations.csv'),
    'short_cycling_9T': pd.read_csv('data/source/9T/Eplus-PPO-load-example-case2_2025-07-17_07:32-res1/episode-10/monitor/observations.csv'),
    'short_cycling_10T': pd.read_csv('data/source/10T/Eplus-PPO-load-example-case2_2025-07-16_09:04-res1/episode-10/monitor/observations.csv'),
}

evaluation_actions = {
    'short_cycling_2T': pd.read_csv('data/source/2T/Eplus-PPO-load-example-case2_2025-07-17_09:28-res1/episode-10/monitor/simulated_actions.csv'),
    'short_cycling_3T': pd.read_csv('data/source/3T/Eplus-PPO-load-example-case2_2025-07-17_09:20-res1/episode-10/monitor/simulated_actions.csv'),
    'short_cycling_4T': pd.read_csv('data/source/4T/Eplus-PPO-load-example-case2_2025-07-17_09:12-res1/episode-10/monitor/simulated_actions.csv'),
    'short_cycling_5T': pd.read_csv('data/source/5T/Eplus-PPO-load-example-case2_2025-07-17_09:01-res1/episode-8/monitor/simulated_actions.csv'),
    'short_cycling_6T': pd.read_csv('data/source/6T/Eplus-PPO-load-example-case2_2025-07-17_08:54-res1/episode-10/monitor/simulated_actions.csv'),
    'short_cycling_7T': pd.read_csv('data/source/7T/Eplus-PPO-load-example-case2_2025-07-17_08:42-res1/episode-10/monitor/simulated_actions.csv'),
    'short_cycling_8T': pd.read_csv('data/source/8T/Eplus-PPO-load-example-case2_2025-07-17_07:44-res1/episode-10/monitor/simulated_actions.csv'),
    'short_cycling_9T': pd.read_csv('data/source/9T/Eplus-PPO-load-example-case2_2025-07-17_07:32-res1/episode-10/monitor/simulated_actions.csv'),
    'short_cycling_10T': pd.read_csv('data/source/10T/Eplus-PPO-load-example-case2_2025-07-16_09:04-res1/episode-10/monitor/simulated_actions.csv')
}

evaluation_infos = {
    'short_cycling_2T': pd.read_csv('data/source/2T/Eplus-PPO-load-example-case2_2025-07-17_09:28-res1/episode-10/monitor/infos.csv'),
    'short_cycling_3T': pd.read_csv('data/source/3T/Eplus-PPO-load-example-case2_2025-07-17_09:20-res1/episode-10/monitor/infos.csv'),
    'short_cycling_4T': pd.read_csv('data/source/4T/Eplus-PPO-load-example-case2_2025-07-17_09:12-res1/episode-10/monitor/infos.csv'),
    'short_cycling_5T': pd.read_csv('data/source/5T/Eplus-PPO-load-example-case2_2025-07-17_09:01-res1/episode-8/monitor/infos.csv'),
    'short_cycling_6T': pd.read_csv('data/source/6T/Eplus-PPO-load-example-case2_2025-07-17_08:54-res1/episode-10/monitor/infos.csv'),
    'short_cycling_7T': pd.read_csv('data/source/7T/Eplus-PPO-load-example-case2_2025-07-17_08:42-res1/episode-10/monitor/infos.csv'),
    'short_cycling_8T': pd.read_csv('data/source/8T/Eplus-PPO-load-example-case2_2025-07-17_07:44-res1/episode-10/monitor/infos.csv'),
    'short_cycling_9T': pd.read_csv('data/source/9T/Eplus-PPO-load-example-case2_2025-07-17_07:32-res1/episode-10/monitor/infos.csv'),
    'short_cycling_10T': pd.read_csv('data/source/10T/Eplus-PPO-load-example-case2_2025-07-16_09:04-res1/episode-10/monitor/infos.csv')
}

#Concatenate the actions and observations
unified = {
    key: pd.concat([
        evaluation_obs[key], 
        evaluation_actions[key], 
        evaluation_infos[key]
    ], axis=1)
    for key in evaluation_obs.keys()
}

evaluation_progress = {
    'short_cycling_2T': pd.read_csv('data/source/2T/Eplus-PPO-load-example-case2_2025-07-17_09:28-res1/progress.csv'),
    'short_cycling_3T': pd.read_csv('data/source/3T/Eplus-PPO-load-example-case2_2025-07-17_09:20-res1/progress.csv'),
    'short_cycling_4T': pd.read_csv('data/source/4T/Eplus-PPO-load-example-case2_2025-07-17_09:12-res1/progress.csv'),
    'short_cycling_5T': pd.read_csv('data/source/5T/Eplus-PPO-load-example-case2_2025-07-17_09:01-res1/progress.csv'),
    'short_cycling_6T': pd.read_csv('data/source/6T/Eplus-PPO-load-example-case2_2025-07-17_08:54-res1/progress.csv'),
    'short_cycling_7T': pd.read_csv('data/source/7T/Eplus-PPO-load-example-case2_2025-07-17_08:42-res1/progress.csv'),
    'short_cycling_8T': pd.read_csv('data/source/8T/Eplus-PPO-load-example-case2_2025-07-17_07:44-res1/progress.csv'),
    'short_cycling_9T': pd.read_csv('data/source/9T/Eplus-PPO-load-example-case2_2025-07-17_07:32-res1/progress.csv'),
    'short_cycling_10T': pd.read_csv('data/source/10T/Eplus-PPO-load-example-case2_2025-07-16_09:04-res1/progress.csv'),
}

# %% [markdown]
# ### Preprocess
#
# Añadimos la columna datetime y filtramos dentro el rango específico que queremos analizar

# %%
for key,df in unified.items():
    unified[key] = add_datetime_column(unified[key])
    unified[key] = filer_interval(unified[key], '2022-11-15 00:00:00', '2023-03-15 23:55:00')
    #Delete rows in May using datetime column
    unified[key] = unified[key][unified[key]['datetime'].dt.month != 5]

# %% [markdown]
# ### Variables

# %%
df_num = len(unified)
zone_names=[
    'Living room', 
    'Kitchen', 
    'Bedroom1', 
    'Bedroom2', 
    'Bedroom3'
]
zone_size = len(zone_names)
temperature_variables = [
    'air_temperature_living',
    'air_temperature_kitchen',
    'air_temperature_bed1',
    'air_temperature_bed2',
    'air_temperature_bed3'
]
flow_variables = [
    'flow_livroom',
    'flow_kitchen',
    'flow_bed1',
    'flow_bed2',
    'flow_bed3',
]
energy_variable = 'heat_source_electricity_rate'
colors = [
    '#1ABC9C',  # Turquesa
    '#3498DB',  # Azul claro
    '#9B59B6',  # Púrpura
    '#E74C3C',  # Rojo
    '#F1C40F',  # Amarillo
    '#2ECC71',  # Verde
    '#E67E22',  # Naranja
    '#95A5A6',  # Gris claro
    '#34495E',  # Azul oscuro grisáceo
    '#D35400'   # Naranja oscuro
]
action_variables = [
    'water_temperature',
    'flow_rate_living',
    'flow_rate_kitchen',
    'flow_rate_bed1',
    'flow_rate_bed2',
    'flow_rate_bed3',
]

# %% [markdown]
# ### Recalculate Means

# %%
mean_temp_violation_dict={}
mean_energy_consumption_dict={}
mean_heat_transfer_rate_dict={}

for key, df in unified.items():
    mean_temp_violation_dict[key] = mean_variable(df, variable='total_temperature_violation')
    mean_energy_consumption_dict[key] = mean_variable(df, variable='total_power_demand')
    mean_heat_transfer_rate_dict[key] = mean_variable(df, variable='heat_source_load_side_heat_transfer_rate')

# %% [markdown]
# ## Results

# %% [markdown]
# ### Temperature vs On/Off flow

# %%
for key,df in unified.items():
    if key=='short_cycling_2T':
        fig = plot_control(df = unified[key], 
                                temperature_variables=temperature_variables,
                                flow_variables=flow_variables,
                                names=[f'Temp {z}' for z in zone_names] + [f'Flow {z}' for z in zone_names],   
                                colors=colors[:10])

        #fig.update_layout(title=key, xaxis_title='', yaxis_title='Temperature (°C)')
        fig.show()

# %% [markdown]
# ### Means by month

# %%
fig = plot_dfs_line_grouped_by_month(dfs = list(unified.values()),
                                     names=list(unified.keys()),
                                     colors = colors[:df_num],
                                     variable='heat_source_load_side_mass_flow_rate')
fig.update_layout(title='HSL MASS FLOW RATE',
                  xaxis_title=None,
                  yaxis_title=None)
#fig.write_image("/workspaces/python-plot-env/outputs/month_plr.png")
fig.show()

# %% [markdown]
# ### Action distribution

# %%
for flow_rate_variable in flow_variables:
    fig = plot_flow_rate_distribution(dfs=list(unified.values()), 
                                   names=list(unified.keys()), 
                                   variable=flow_rate_variable,
                                   colors = colors[:df_num])
    fig.update_layout(
        title = f'{flow_rate_variable} Distribution',
        yaxis_title = '',
        showlegend=False,
    )
    #fig.write_image(f"/workspaces/python-plot-env/outputs/distribution_{action_variable}.png")
    fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 for flow_rate_variable in flow_variables:
# ----> 2     fig = plot_flow_rate_distribution(dfs=list(unified.values()),
#       3                                    names=list(unified.keys()),
#       4                                    variable=flow_rate_variable,
#       5                                    colors = colors[:df_num])
#       6     fig.update_layout(
#       7         title = f'{flow_rate_variable} Distribution',
#       8         yaxis_title = '',
#       9         showlegend=False,
#      10     )
#      11     #fig.write_image(f"/workspaces/python-plot-env/outputs/distribution_{action_variable}.png")
#
# NameError: name 'plot_flow_rate_distribution' is not defined

# %% [markdown]
# ### BoxPlot

# %%
fig = plot_dfs_boxplot(dfs = evaluation_progress.values(), 
                       names = evaluation_progress.keys(), 
                       variable = 'comfort_violation_time(%)',
                       colors = colors[:df_num])
fig.update_layout(title='Comfort violation time (% of episode)',
                  yaxis_title='')
fig.write_image("/workspaces/python-plot-env/outputs/boxplot_comfort_violation_time.png")

# %%
fig = plot_dfs_boxplot(dfs = evaluation_progress.values(), 
                       names = evaluation_progress.keys(), 
                       variable='mean_temperature_violation', 
                       colors = colors[:df_num])
fig.update_layout(title='Mean temperature violation',
                  yaxis_title='Temperature violation (ºC)')
fig.write_image("/workspaces/python-plot-env/outputs/boxplot_temperature_violation.png")

# %%
fig = plot_dfs_boxplot(dfs = evaluation_progress.values(), 
                       names = evaluation_progress.keys(), 
                       variable='mean_power_demand', 
                       colors = colors[:df_num])
fig.update_layout(title='Mean power demand',
                  yaxis_title='Power demand (W)')
fig.write_image("/workspaces/python-plot-env/outputs/boxplot_power_demand.png")
